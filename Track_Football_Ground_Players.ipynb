# %%
# !nvidia-smi
# Out:
# Wed Jan 10 14:03:13 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.2/699.2 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
# !yolo task=detect mode=train model=yolov8m.pt data="/content/football-players-detection.v4i.yolov8/data.yaml" epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
infer=YOLO("/content/drive/MyDrive/YOLO/football-players-detection.v4i.yolov8/runs/detect/train2/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/YOLO/football-players-detection.v4i.yolov8/test/images", save=True, save_txt=True)
# Out:
# image 1/13 /content/drive/MyDrive/YOLO/football-players-detection.v4i.yolov8/test/images/40cd38_7_6_png.rf.68ef7fcd663cdf0f5b96bacdbcd94e07.jpg: 384x640 21 players, 1 referee, 26.2ms
# image 2/13 /content/drive/MyDrive/YOLO/football-players-detection.v4i.yolov8/test/images/42ba34_1_5_png.rf.4337fde8fbe3640cf4351fb41ac9c3ca.jpg: 384x640 1 goalkeeper, 20 players, 3 referees, 25.3ms
# image 3/13 /content/drive/MyDrive/YOLO/football-players-detection.v4i.yolov8/test/images/42ba34_5_5_png.rf.ceb556bd4c92d41496ae1d8c56600c4a.jpg: 384x640 1 goalkeeper, 18 players, 2 referees, 25.2ms
# image 4/13 /content/drive/MyDrive/YOLO/football-players-detection.v4i.yolov8/test/images/4b770a_1_4_png.rf.5a45b3b841a06de414ceb802e34c136f.jpg: 384x640 1 goalkeeper, 18 players, 3 referees, 25.1ms
# image 5/13 /content/drive/MyDrive/YOLO/football-players-detection.v4i.yolov8/test/images/4b770a_3_6_png.rf.d0d9403f2f73ca0da7a6a1373c02b749.jpg: 384x640 1 goalkeeper, 21 players, 1 referee, 25.1ms
# ...
